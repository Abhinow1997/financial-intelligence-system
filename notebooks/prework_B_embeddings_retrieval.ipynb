# %% [markdown]
# # Pre-work B - Embeddings & Retrieval
#
# - Embeddings + nearest-neighbor retrieval
# - Find a semantic false positive
# - Sentiment: lexicon vs FinBERT vs frontier LLM
# - Cost / stability comparison

# %%
# TODO
