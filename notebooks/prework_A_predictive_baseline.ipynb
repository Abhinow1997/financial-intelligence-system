# %% [markdown]
# # Pre-work A - Predictive Baseline
#
# - Logistic baseline -> XGBoost with a TIME split
# - Threshold sweep + confusion-cost matrix
# - Plant a leakage feature and detect it
# - Statistical performance vs economic usefulness (expected loss)

# %%
# TODO
